# %%
import pandas as pd
from mapping.utils.connection import Connection

# %%
radient_prod = Connection()
# Out:
# Connected to server : SUCCESS

# %%
formd_funds = radient_prod.sql_to_frame('../cache/formd_funds.csv')
formd_funds.to_pickle('../storage/formd_funds.pkl')
# Out:
# ---------------------------------------------------------------------------
# SyntaxError                               Traceback (most recent call last)
# c:\users\karthikeya\appdata\local\programs\python\python37\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1680         try:
# -> 1681             cur.execute(*args, **kwargs)
#    1682             return cur
#
# SyntaxError: syntax error at or near "firm_id"
# LINE 1: firm_id,form_d_funds,cik_no_fund
#         ^
#
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# C:\Users\KARTHI~1\AppData\Local\Temp/ipykernel_24472/4038684998.py in <module>
# ----> 1 formd_funds = radient_prod.sql_to_frame('../cache/formd_funds.csv')
#       2 formd_funds.to_pickle('../storage/formd_funds.pkl')
#
# ~\Forest\tejaDataClean\notebooks\mapping\utils\connection.py in sql_to_frame(self, filename)
# ...

# %%
formadv_firms = radient_prod.sql_to_frame('../cache/formadv_firms.csv')
formadv_firms.to_pickle('../storage/formadv_firms.pkl')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# C:\Users\KARTHI~1\AppData\Local\Temp/ipykernel_24472/34701543.py in <module>
# ----> 1 formadv_firms = radient_prod.sql_to_frame('../cache/formadv_firms.csv')
#       2 formadv_firms.to_pickle('../storage/formadv_firms.pkl')
#
# ~\Forest\tejaDataClean\notebooks\mapping\utils\connection.py in sql_to_frame(self, filename)
#      21
#      22         with open(filename, 'r') as file:
# ---> 23             query = file.read()
#      24
#      25         dataframe = pd.read_sql(query, self.engine)
#
# c:\users\karthikeya\appdata\local\programs\python\python37\lib\encodings\cp1252.py in decode(self, input, final)
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
#      22     def decode(self, input, final=False):
# ---> 23         return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#      24
# ...

# %%
formadv_funds = radient_prod.sql_to_frame('../cache/formadv_funds.csv')
formadv_funds.to_pickle('../storage/formadv_funds.pkl')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# C:\Users\KARTHI~1\AppData\Local\Temp/ipykernel_24472/2297579653.py in <module>
# ----> 1 formadv_funds = radient_prod.sql_to_frame('../cache/formadv_funds.csv')
#       2 formadv_funds.to_pickle('../storage/formadv_funds.pkl')
#
# ~\Forest\tejaDataClean\notebooks\mapping\utils\connection.py in sql_to_frame(self, filename)
#      21
#      22         with open(filename, 'r') as file:
# ---> 23             query = file.read()
#      24
#      25         dataframe = pd.read_sql(query, self.engine)
#
# c:\users\karthikeya\appdata\local\programs\python\python37\lib\encodings\cp1252.py in decode(self, input, final)
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
#      22     def decode(self, input, final=False):
# ---> 23         return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#      24
# ...

# %%
related_partners = radient_prod.sql_to_frame('../cache/related_partners.csv')
related_partners.to_pickle('../storage/related_partners.pkl')
# Out:
# ---------------------------------------------------------------------------
# SyntaxError                               Traceback (most recent call last)
# c:\users\karthikeya\appdata\local\programs\python\python37\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1680         try:
# -> 1681             cur.execute(*args, **kwargs)
#    1682             return cur
#
# SyntaxError: syntax error at or near "form_d_value_id"
# LINE 1: form_d_value_id,related_partners,cik_no_related_partners
#         ^
#
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# C:\Users\KARTHI~1\AppData\Local\Temp/ipykernel_24472/1190460370.py in <module>
# ----> 1 related_partners = radient_prod.sql_to_frame('../cache/related_partners.csv')
#       2 related_partners.to_pickle('../storage/related_partners.pkl')
#
# ...

# %%
direct_owners = radient_prod.sql_to_frame('../cache/direct_owners.csv')
direct_owners.to_pickle('../storage/direct_owners.pkl')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# C:\Users\KARTHI~1\AppData\Local\Temp/ipykernel_24472/2676150733.py in <module>
# ----> 1 direct_owners = radient_prod.sql_to_frame('../cache/direct_owners.csv')
#       2 direct_owners.to_pickle('../storage/direct_owners.pkl')
#
# ~\Forest\tejaDataClean\notebooks\mapping\utils\connection.py in sql_to_frame(self, filename)
#      21
#      22         with open(filename, 'r') as file:
# ---> 23             query = file.read()
#      24
#      25         dataframe = pd.read_sql(query, self.engine)
#
# c:\users\karthikeya\appdata\local\programs\python\python37\lib\encodings\cp1252.py in decode(self, input, final)
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
#      22     def decode(self, input, final=False):
# ---> 23         return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#      24
# ...

# %%
radient_prod.close()
